# %%
library(Rtsne)
library(ggplot2)
library(dplyr)

# %%
library(FNN)

# %%
predata <- read.table("filter.scimpute_count.Norm_RLE.Batch_null.domains_combined.txt", header = T, row.names = 1, sep = "\t")
postdata <- read.table("filter.scimpute_count.Norm_RLE.Batch_RUV.domains_combined.txt", header = T, row.names = 1, sep = "\t")

# %%
batch_info <- read.table("~/Bioinfos/data/scirep_batch.txt", sep = ",", header = T, row.names = 1, stringsAsFactors = T)
batch_info$RNA.Isolation.batch <- factor(batch_info$RNA.Isolation.batch)
batch_temp <- batch_info
batch_temp$names <- rownames(batch_info)
batch_temp <- arrange(batch_temp, names)
rownames(batch_temp) <- batch_temp$names
batch_info <- as.data.frame(batch_temp[,-ncol(batch_temp)])

# %%
sample_class <- as.factor(c(rep("Colorectal Cancer", times = 100), rep("Normal", times = 50), 
                                          rep("Normal", times = 6), rep("Prostate Cancer", times = 36)))

# %%
#batch_info[which(batch_info$RNA.Isolation.batch == 7), ]

# %%
temp <- as.data.frame(t(predata))
temp$names <- rownames(temp)
temp <- arrange(temp, names)
rownames(temp) <- temp$names
predata <- as.data.frame(temp[,-ncol(temp)])

temp <- as.data.frame(t(postdata))
temp$names <- rownames(temp)
temp <- arrange(temp, names)
rownames(temp) <- temp$names
postdata <- as.data.frame(temp[,-ncol(temp)])

# %%
# Out:
#   [1] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#   [5] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#   [9] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [13] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [17] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [21] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [25] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [29] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [33] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [37] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [41] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [45] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [49] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [53] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [57] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [61] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [65] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [69] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [73] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [77] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [81] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [85] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [89] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [93] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
#  [97] Colorectal Cancer Colorectal Cancer Colorectal Cancer Colorectal Cancer
# [101] Normal            Normal            Normal            Normal
# [105] Normal            Normal            Normal            Normal
# [109] Normal            Normal            Normal            Normal
# [113] Normal            Normal            Normal            Normal
# [117] Normal            Normal            Normal            Normal
# [121] Normal            Normal            Normal            Normal
# [125] Normal            Normal            Normal            Normal
# [129] Normal            Normal            Normal            Normal
# [133] Normal            Normal            Normal            Normal
# [137] Normal            Normal            Normal            Normal
# [141] Normal            Normal            Normal            Normal
# [145] Normal            Normal            Normal            Normal
# [149] Normal            Normal            Normal            Normal
# [153] Normal            Normal            Normal            Normal
# [157] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [161] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [165] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [169] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [173] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [177] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [181] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [185] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# [189] Prostate Cancer   Prostate Cancer   Prostate Cancer   Prostate Cancer
# Levels: Colorectal Cancer Normal Prostate Cancer

# %%
p <- Rtsne(predata, dims = 1)
q <- Rtsne(postdata, dims = 1)

# %%
pre_p <- cbind(batch_info$RNA.Isolation.batch, p$Y)
post_q <- cbind(batch_info$RNA.Isolation.batch, q$Y)
sum_data <- as.data.frame(rbind(pre_p, post_q))
foo <- c(rep("Before Batch Removal", times = length(p$Y)), rep("After Batch Removal", times = length(q$Y)))
sum_data$Type <- sample_class
sum_data$State <- foo

# %%
names(sum_data) <- c("Batch", "t_SNE", "Type", "State")
sum_data$Batch <- as.factor(sum_data$Batch)
sum_data$Type <- as.factor(sum_data$Type)
sum_data$State <- as.factor(sum_data$State)

# %%
sum_data
# Out:
#     Batch t_SNE       Type              State
# 1   2       5.7892082 Colorectal Cancer Before Batch Removal
# 2   3       2.9437147 Colorectal Cancer Before Batch Removal
# 3   3     -11.6434857 Colorectal Cancer Before Batch Removal
# 4   3       0.6551440 Colorectal Cancer Before Batch Removal
# 5   4      -3.9988097 Colorectal Cancer Before Batch Removal
# 6   4      -6.1821744 Colorectal Cancer Before Batch Removal
# 7   4      -7.0273897 Colorectal Cancer Before Batch Removal
# 8   5      -2.6229096 Colorectal Cancer Before Batch Removal
# 9   5      -1.7272982 Colorectal Cancer Before Batch Removal
# 10  5      -0.2846681 Colorectal Cancer Before Batch Removal
# 11  7      -4.4478950 Colorectal Cancer Before Batch Removal
# 12  2       6.5913080 Colorectal Cancer Before Batch Removal
# 13  7      -4.3277640 Colorectal Cancer Before Batch Removal
# 14  7      -8.0048110 Colorectal Cancer Before Batch Removal
# 15  8      -0.9046871 Colorectal Cancer Before Batch Removal
# 16  8      -3.1199244 Colorectal Cancer Before Batch Removal
# 17  8      -5.7772337 Colorectal Cancer Before Batch Removal
# 18  3       2.5111551 Colorectal Cancer Before Batch Removal
# 19  2       6.6271821 Colorectal Cancer Before Batch Removal
# 20  6       3.6181058 Colorectal Cancer Before Batch Removal
# 21  6       4.0543704 Colorectal Cancer Before Batch Removal
# 22  6       3.8431300 Colorectal Cancer Before Batch Removal
# 23  1       5.5895081 Colorectal Cancer Before Batch Removal
# 24  1       6.5106083 Colorectal Cancer Before Batch Removal
# 25  1       6.2434845 Colorectal Cancer Before Batch Removal
# 26  2       3.6331375 Colorectal Cancer Before Batch Removal
# 27  3       0.8173539 Colorectal Cancer Before Batch Removal
# 28  3       5.5887414 Colorectal Cancer Before Batch Removal
# 29  3       0.7122047 Colorectal Cancer Before Batch Removal
# 30  4      -6.7748455 Colorectal Cancer Before Batch Removal
# ⋮   ⋮     ⋮           ⋮                 ⋮
# 355 1      8.31309766 Prostate Cancer   After Batch Removal
# 356 1      8.53423503 Prostate Cancer   After Batch Removal
# 357 1     -2.07539777 Prostate Cancer   After Batch Removal
# 358 3      5.66489516 Prostate Cancer   After Batch Removal
# 359 3      8.82752313 Prostate Cancer   After Batch Removal
# 360 2     -7.28134686 Prostate Cancer   After Batch Removal
# 361 3      8.28152646 Prostate Cancer   After Batch Removal
# 362 4      4.97683033 Prostate Cancer   After Batch Removal
# 363 4      0.56626201 Prostate Cancer   After Batch Removal
# 364 4      3.73373540 Prostate Cancer   After Batch Removal
# 365 4      0.07400761 Prostate Cancer   After Batch Removal
# 366 4     -0.91604416 Prostate Cancer   After Batch Removal
# 367 4      0.07909684 Prostate Cancer   After Batch Removal
# 368 5     -0.52792292 Prostate Cancer   After Batch Removal
# 369 5      0.50226440 Prostate Cancer   After Batch Removal
# 370 5      0.09240194 Prostate Cancer   After Batch Removal
# 371 2     -8.00817012 Prostate Cancer   After Batch Removal
# 372 5      2.38141228 Prostate Cancer   After Batch Removal
# 373 7      5.47083760 Prostate Cancer   After Batch Removal
# 374 7      5.34042053 Prostate Cancer   After Batch Removal
# 375 7      7.55881554 Prostate Cancer   After Batch Removal
# 376 7      4.81699849 Prostate Cancer   After Batch Removal
# 377 7      4.09870502 Prostate Cancer   After Batch Removal
# 378 8     -4.76287621 Prostate Cancer   After Batch Removal
# 379 2     -8.49251101 Prostate Cancer   After Batch Removal
# 380 2     -5.21315621 Prostate Cancer   After Batch Removal
# 381 2     -5.10230534 Prostate Cancer   After Batch Removal
# 382 6     -5.46172065 Prostate Cancer   After Batch Removal
# 383 6      2.83844994 Prostate Cancer   After Batch Removal
# 384 6      4.96979113 Prostate Cancer   After Batch Removal

# %%
s <- ggplot(data = sum_data, aes(x = t_SNE, col = Batch))  + geom_density() + facet_wrap(~State)
s <- s + scale_fill_brewer(palette="Set2") + 
        theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(),
        panel.background = element_blank(),axis.line = element_line(colour = "black")) 
pdf("test_for_batch.pdf", 10, 6)
s
dev.off()
# Out:
# png
#   2

# %%
s <- ggplot(data = sum_data, aes(x = t_SNE, col = Type))  + geom_density() + facet_wrap(~State)
s <- s + scale_fill_brewer(palette="Set2") + 
        theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(),
        panel.background = element_blank(),axis.line = element_line(colour = "black")) 
pdf("test_for_type.pdf", 10, 6)
s
dev.off()
# Out:
# png
#   2

# %%
p <- Rtsne(postdata, dims = 1)
tSNE_Vis_before <- as.data.frame(cbind(batch_info$RNA.Isolation.batch, p$Y))
names(tSNE_Vis_before) <- c("Batch", "Y")
s <- ggplot(data = tSNE_Vis_before, aes(x = Y, col = Batch)) + geom_density() 
s <- s + scale_fill_brewer(palette="Set2") + 
        theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(),
        panel.background = element_blank(),axis.line = element_line(colour = "black")) 
png("before.png")
s
dev.off()

p <- Rtsne(predata, dims = 1)
tSNE_Vis_after <- as.data.frame(cbind(batch_info$RNA.Isolation.batch, p$Y))
names(tSNE_Vis_after) <- c("Batch", "Y")
tSNE_Vis_after$Batch <- factor(tSNE_Vis_after$Batch)
s <- ggplot(data = tSNE_Vis_after, aes(x = Y, col = Batch)) + geom_density()
s <- s + scale_fill_brewer(palette="Set2") + 
        theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(),
        panel.background = element_blank(),axis.line = element_line(colour = "black")) 
png("after.png")
s
dev.off()
# Out:
# png
#   2
# png
#   2

# %%
## Test for the cancer/normal -- after
p <- Rtsne(postdata, dims = 1)
tSNE_Vis_after <- as.data.frame(cbind(sample_class, p$Y))
names(tSNE_Vis_after) <- c("Type", "Y")
s <- ggplot(data = tSNE_Vis_after, aes(x = Y, fill = Type)) + geom_density()
s <- s + scale_fill_brewer(palette="Set2") + 
        theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(),
        panel.background = element_blank(),axis.line = element_line(colour = "black")) 
png("after_test.png")
s
dev.off()

p <- Rtsne(predata, dims = 1)
tSNE_Vis_before <- as.data.frame(cbind(sample_class, p$Y))
names(tSNE_Vis_before) <- c("Type", "Y")
s <- ggplot(data = tSNE_Vis_before, aes(x = Y, fill = Type)) + geom_density()
s <- s + scale_fill_brewer(palette="Set2") + 
        theme(panel.grid.major =element_blank(), panel.grid.minor = element_blank(),
        panel.background = element_blank(),axis.line = element_line(colour = "black")) 
png("before_test.png")
s
dev.off()
# Out:
# png
#   2
# png
#   2

# %%
t1 <- tSNE_Vis_after$Y[which(tSNE_Vis_after$Type == 1)]
t0 <- tSNE_Vis_after$Y[which(tSNE_Vis_after$Type == 0)]
t2 <- tSNE_Vis_after$Y[which(tSNE_Vis_after$Type == 2)]

b1 <- tSNE_Vis_before$Y[which(tSNE_Vis_after$Type == 1)]
b0 <- tSNE_Vis_before$Y[which(tSNE_Vis_after$Type == 0)]
b2 <- tSNE_Vis_before$Y[which(tSNE_Vis_after$Type == 2)]

# %%
KL.divergence(t1, t0, k = 1)
KL.divergence(b1, b0, k = 1)
# Out:
# [1] 0.3778294
# [1] 0.3195271
